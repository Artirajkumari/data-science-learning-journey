# %%
l= [ 23,45,56,78,67,90]
l
# Out:
# [23, 45, 56, 78, 67, 90]

# %%
# homogenous= shoud be same datatype all the data in the array
# hetrogenous= different datatype in the list

# 1. in the list we can not do element wise operation but in array we can
#  array to list conversion is possible and also list to array conversion
#  it possible but we will lose the dimension
#  list is hetrogenous datatyoe but numpy is homogenous datatype.

# %%
pip install numpy

# %%
import numpy as np

# %%
# creating a array
b = np.array(object = [1,2.3,5.6,7.8,3.4], dtype= None)
b
# Out:
# array([1. , 2.3, 5.6, 7.8, 3.4])

# %%
# add  2 in array each records
b+2
# Out:
# array([3. , 4.3, 7.6, 9.8, 5.4])

# %%
# create a list
l1= [2,3,4,5,6]
type(l1)
# Out:
# list

# %%
# converting list into array
a1= np.array(l1)
type(l1)
# Out:
# list

# %%
# again change array into list 
l2= list(a1)
l2
# Out:
# [2, 3, 4, 5, 6]

# %%
arr = np.array(object= [1,23,45,6,7.8], dtype= int)
arr
print(arr)
print(type(arr))
print("the dimension of array:   ", arr.ndim)
print("the size of array:   ", arr.size)
print("the position of max num of array:   ", arr.argmax())
print("the  clm and rows of array:   ", arr.shape)
# Out:
# [ 1 23 45  6  7]
# <class 'numpy.ndarray'>
# the dimension of array:    1
# the size of array:    5
# the position of max num of array:    2
# the  clm and rows of array:    (5,)

# %%
# fill is used to fill the value in array each records
arr.fill(7)
arr
# Out:
# array([7, 7, 7, 7, 7])

# %%
arr.repeat(repeats = 20, axis = None)
arr
# Out:
# array([7, 7, 7, 7, 7])

# %%
import numpy as np

# %%
arr= np.array([[[1,2,4,8],
      [3,4,5,6],
      [4,5,6,7],
      [3,4,5,6]]])
arr
# Out:
# array([[[1, 2, 4, 8],
#         [3, 4, 5, 6],
#         [4, 5, 6, 7],
#         [3, 4, 5, 6]]])

# %%
arr1= np.array([[1,2,3,4], [3,4,5,6]])
arr1
# Out:
# array([[1, 2, 3, 4],
#        [3, 4, 5, 6]])

# %%
arr1[1][2]
# Out:
# 5

# %%
arr1. mean()
# Out:
# 3.5

# %%
print(arr1.reshape(8))
# Out:
# [1 2 3 4 3 4 5 6]

# %%
print(arr1. reshape(8,1))

print(arr1.reshape(-1))
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [3]
#  [4]
#  [5]
#  [6]]
# [1 2 3 4 3 4 5 6]

# %%
print(arr1.reshape(-1))
# Out:
# [1 2 3 4 3 4 5 6]

# %%
arr1.reshape(2,4)
# Out:
# array([[1, 2, 3, 4],
#        [3, 4, 5, 6]])

# %%
np.random.rand(5,5)
# Out:
# array([[0.49847001, 0.04803506, 0.8091865 , 0.95469946, 0.21533485],
#        [0.38110487, 0.50703293, 0.85704968, 0.88320868, 0.74178311],
#        [0.85375934, 0.77732702, 0.23446046, 0.66453166, 0.46340524],
#        [0.44994005, 0.28021456, 0.68372656, 0.32660664, 0.76041474],
#        [0.80165429, 0.32369854, 0.01445064, 0.02409674, 0.49706139]])

# %%
np.arange(2,20,2,dtype= 'int')
# Out:
# array([ 2,  4,  6,  8, 10, 12, 14, 16, 18])

# %%
np.random.randint(1,5,size = (5,5)). astype(int)
# Out:
# array([[4, 3, 1, 2, 1],
#        [1, 2, 1, 4, 2],
#        [2, 2, 3, 4, 2],
#        [1, 1, 4, 1, 2],
#        [4, 3, 3, 4, 4]])

# %%
import pandas as pd

# %%
cars_data = pd.read_csv( r"C:\Users\ArtiR\Downloads\mtcars.csv")
cars_data
# Out:
#            manufacturer   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
del cars_data['manufacturer']

# %%
cars_data
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
cars_data.shape
# Out:
# (32, 11)

# %%
cars_data.dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18876\4182656632.py in ?()
# ----> 1 cars_data.dtype()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 2.9 KB

# %%
cars_data.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
from matplotlib import pyplot as plt
# import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (8,5))
plt.hist(x='mpg', data = cars_data)
plt.title('MPG distribution')
plt.xlabel('MPG')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import seaborn as sns

# %%
plt.figure(figsize = (8,5))
sns.countplot(x='cyl', y= None,data = cars_data, hue= 'cyl') ## hue for color 
plt.title("cyl distribution")
plt.show()

# %%
sns.barplot(x= 'cyl', y= 'mpg', data = cars_data )
plt.title('cyl vs mpg relationship')
plt.show()

# %%
cars_data
# Out:
#            manufacturer   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
sns.barplot(x= 'gear', y= 'mpg', data = cars_data )
plt.title('gear vs mpg relationship')
plt.show()

# %%
sns.barplot(x='wt',y='mpg', data = cars_data)
plt.title('wt vs mpg relationship')
plt.xticks( rotation = 90)
plt.show()

# %%
sns.scatterplot(x='wt',y='mpg', data = cars_data)
plt.title('wt vs mpg relationship')

plt.show()

# %%
sns.pairplot(data= cars_data)

# %%
cars_data
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
corr = cars_data.corr().round(2)
corr
# Out:
#        mpg   cyl  disp    hp  drat    wt  qsec    vs    am  gear  carb
# mpg   1.00 -0.85 -0.85 -0.78  0.68 -0.87  0.42  0.66  0.60  0.48 -0.55
# cyl  -0.85  1.00  0.90  0.83 -0.70  0.78 -0.59 -0.81 -0.52 -0.49  0.53
# disp -0.85  0.90  1.00  0.79 -0.71  0.89 -0.43 -0.71 -0.59 -0.56  0.39
# hp   -0.78  0.83  0.79  1.00 -0.45  0.66 -0.71 -0.72 -0.24 -0.13  0.75
# drat  0.68 -0.70 -0.71 -0.45  1.00 -0.71  0.09  0.44  0.71  0.70 -0.09
# wt   -0.87  0.78  0.89  0.66 -0.71  1.00 -0.17 -0.55 -0.69 -0.58  0.43
# qsec  0.42 -0.59 -0.43 -0.71  0.09 -0.17  1.00  0.74 -0.23 -0.21 -0.66
# vs    0.66 -0.81 -0.71 -0.72  0.44 -0.55  0.74  1.00  0.17  0.21 -0.57
# am    0.60 -0.52 -0.59 -0.24  0.71 -0.69 -0.23  0.17  1.00  0.79  0.06
# gear  0.48 -0.49 -0.56 -0.13  0.70 -0.58 -0.21  0.21  0.79  1.00  0.27
# carb -0.55  0.53  0.39  0.75 -0.09  0.43 -0.66 -0.57  0.06  0.27  1.00

# %%
#pip install seaborn --upgrade
plt.figure(figsize= (10,8))
sns.heatmap(data= corr,annot = True)
# Out:
# <Axes: >

# %%
cars_data['cyl'].value.count()

# %%
plt.pie(x = cars_data['cyl'].value_counts(),
        labels =[8,4,6],autopct = '%0.1f%%',explode= [0,0.03,0])  # autopct  used to place of decimal after the number 
plt.show()                                                        # explod is used to division of pie charts

# %%
plt.boxplot(x= 'wt',data= cars_data, vert = False) # used to boxplot to contribution of the data and outlayers present in the data
plt.show()
