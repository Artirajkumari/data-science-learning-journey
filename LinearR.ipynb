# %%
import pandas as pd

# %%
news= pd.read_csv(r"D:\All data\NewspaperData.csv")

# %%
news
# Out:
#                          Newspaper     daily    sunday
# 0                    Baltimore Sun   391.952   488.506
# 1                     Boston Globe   516.981   798.298
# 2                    Boston Herald   355.628   235.084
# 3               Charlotte Observer   238.555   299.451
# 4                Chicago Sun Times   537.780   559.093
# 5                  Chicago Tribune   733.775  1133.249
# 6              Cincinnati Enquirer   198.832   348.744
# 7                      Denver Post   252.624   417.779
# 8              Des Moines Register   206.204   344.522
# 9                 Hartford Courant   231.177   323.084
# 10               Houston Chronicle   449.755   620.752
# 11                Kansas City Star   288.571   423.305
# 12         Los Angeles Daily  News   185.736   202.614
# 13               Los Angeles Times  1164.388  1531.527
# 14                    Miami Herald   444.581   553.479
# 15        Minneapolis Star Tribune   412.871   685.975
# ...

# %%
del news['Newspaper']

# %%
news
# Out:
#        daily    sunday
# 0    391.952   488.506
# 1    516.981   798.298
# 2    355.628   235.084
# 3    238.555   299.451
# 4    537.780   559.093
# 5    733.775  1133.249
# 6    198.832   348.744
# 7    252.624   417.779
# 8    206.204   344.522
# 9    231.177   323.084
# 10   449.755   620.752
# 11   288.571   423.305
# 12   185.736   202.614
# 13  1164.388  1531.527
# 14   444.581   553.479
# 15   412.871   685.975
# 16   272.280   324.241
# 17   781.796   983.240
# 18  1209.225  1762.015
# 19   825.512   960.308
# 20   223.748   284.611
# 21   354.843   407.760
# 22   515.523   982.663
# 23   220.465   557.000
# 24   337.672   440.923
# 25   197.120   268.060
# 26   133.239   262.048
# 27   374.009   432.502
# 28   273.844   338.355
# 29   570.364   704.322
# 30   391.286   585.681
# 31   201.860   267.781
# 32   321.626   408.343
# 33   838.902  1165.567

# %%
# to check the corelation or not we use scatter plot

# %%
import seaborn as sns

# %%
sns.scatterplot(data= news, x= 'daily', y= 'sunday')
# Out:
# <Axes: xlabel='daily', ylabel='sunday'>

# %%
news.corr()
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %%
news.shape
# Out:
# (34, 2)

# %%
news.dtypes
# Out:
# daily     float64
# sunday    float64
# dtype: object

# %%
news.columns
# Out:
# Index(['daily', 'sunday'], dtype='object')

# %%
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   daily   34 non-null     float64
#  1   sunday  34 non-null     float64
# dtypes: float64(2)
# memory usage: 676.0 bytes

# %%
news.describe()
# Out:
#              daily       sunday
# count    34.000000    34.000000
# mean    430.962471   591.202412
# std     269.211470   376.418051
# min     133.239000   202.614000
# 25%     233.021500   327.769500
# 50%     355.235500   436.712500
# 75%     516.616500   699.735250
# max    1209.225000  1762.015000

# %%
news.head()
# Out:
#      daily   sunday
# 0  391.952  488.506
# 1  516.981  798.298
# 2  355.628  235.084
# 3  238.555  299.451
# 4  537.780  559.093

# %%
news.tail()
# Out:
#       daily    sunday
# 29  570.364   704.322
# 30  391.286   585.681
# 31  201.860   267.781
# 32  321.626   408.343
# 33  838.902  1165.567

# %%
news.isnull()
# Out:
#     daily  sunday
# 0   False   False
# 1   False   False
# 2   False   False
# 3   False   False
# 4   False   False
# 5   False   False
# 6   False   False
# 7   False   False
# 8   False   False
# 9   False   False
# 10  False   False
# 11  False   False
# 12  False   False
# 13  False   False
# 14  False   False
# 15  False   False
# 16  False   False
# 17  False   False
# 18  False   False
# 19  False   False
# 20  False   False
# 21  False   False
# 22  False   False
# 23  False   False
# 24  False   False
# 25  False   False
# 26  False   False
# 27  False   False
# 28  False   False
# 29  False   False
# 30  False   False
# 31  False   False
# 32  False   False
# 33  False   False

# %%
news.isnull().sum()
# Out:
# daily     0
# sunday    0
# dtype: int64

# %%
x= df[["daily"]]
print(x)
y= news[["sunday"]]
print(y)
# Out:
#        daily
# 0    391.952
# 1    516.981
# 2    355.628
# 3    238.555
# 4    537.780
# 5    733.775
# 6    198.832
# 7    252.624
# 8    206.204
# 9    231.177
# 10   449.755
# 11   288.571
# 12   185.736
# 13  1164.388
# 14   444.581
# 15   412.871
# 16   272.280
# 17   781.796
# 18  1209.225
# 19   825.512
# 20   223.748
# 21   354.843
# 22   515.523
# 23   220.465
# 24   337.672
# 25   197.120
# 26   133.239
# 27   374.009
# 28   273.844
# 29   570.364
# 30   391.286
# 31   201.860
# 32   321.626
# 33   838.902
#       sunday
# 0    488.506
# 1    798.298
# 2    235.084
# 3    299.451
# 4    559.093
# 5   1133.249
# 6    348.744
# 7    417.779
# 8    344.522
# 9    323.084
# 10   620.752
# 11   423.305
# 12   202.614
# 13  1531.527
# 14   553.479
# 15   685.975
# 16   324.241
# 17   983.240
# 18  1762.015
# 19   960.308
# 20   284.611
# 21   407.760
# 22   982.663
# 23   557.000
# 24   440.923
# 25   268.060
# 26   262.048
# 27   432.502
# 28   338.355
# 29   704.322
# ...

# %%
# to do all machine learning algorithm we use sklearn 
from sklearn.linear_model import LinearRegression

# %%
slr = LinearRegression()  # Model building
slr.fit(x,y)   # Model Training
y_pred= slr.predict(x)

# %%
y_pred
# Out:
# array([[ 538.93950861],
#        [ 706.44270505],
#        [ 490.27570976],
#        [ 333.43128393],
#        [ 734.3074323 ],
#        [ 996.88482623],
#        [ 280.21379461],
#        [ 352.27973085],
#        [ 290.0901718 ],
#        [ 323.54686845],
#        [ 616.37904075],
#        [ 400.43845725],
#        [ 262.66889014],
#        [1573.78341718],
#        [ 609.4473566 ],
#        [ 566.96500163],
#        [ 378.61316413],
#        [1061.21926861],
#        [1633.85220777],
#        [1119.78623895],
#        [ 313.59412751],
#        [ 489.22403367],
#        [ 704.48940094],
#        [ 309.19584396],
#        [ 466.21979157],
#        [ 277.92020294],
#        [ 192.33788451],
#        [ 514.90100672],
#        [ 380.70847801],
#        [ 777.96069796],
#        [ 538.04725858],
#        [ 284.2704509 ],
#        [ 444.72272856],
#        [1137.72501956]])

# %%
# how to predict the value machine= base on below
# linear formula=  ax+b , alpha= coef , bitaa= intercept
print(slr.coef_)
print(slr.intercept_)
# Out:
# [[1.33971476]]
# [13.83562991]

# %%
#linear eq= 1.33971476*x=13.83562991
(1.33971476*391.95)+13.83562991
# Out:
# 538.9368300919999

# %%
#  to cheack the accuracy 
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error,root_mean_squared_error, mean_absolute_percentage_error

# %%
r2_score(y,y_pred) # range is (0,1) sso it is near to 1 that is  best fit
# Out:
# 0.9180596895873295

# %%
 # these are  showing the error of model , here no any range as much possible error is less than  then it is fit model
print( mean_absolute_error(y,y_pred))
print(mean_squared_error(y,y_pred))
print(root_mean_squared_error(y,y_pred))
print(mean_absolute_percentage_error(y,y_pred))
# Out:
# 80.1327444999346
# 11268.6920722415
# 106.15409588066538
# 0.16397396761814972

# %% [markdown]
# #Multcoliearity

# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\ArtiR\Downloads\Cars.csv")

# %%
df
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
#Data Validation
skelearn.model_selection import train_test_split
# Out:
#   Cell In[13], line 2
#     skelearn.model_selection import train_test_split
#                              ^
# SyntaxError: invalid syntax

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state= 15) # random_stete id used to fix the data

# %%
# always check the size of data
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
# import libarary
from skelearn.linear_model import LinearRegression

# %%
#model building
mlr= LinearRegression()
# train the model
mlr.fit(x_train,y_train)

# %%
#test  the model
# training accuracy
y_train_pred=mlr.predict(x_train)

# %%
from skelearn.metrics import r2_score

# %%
r2_score(y_train,y_train_pred)

# %%
#Test accuracy
y_test_pred=mlr.predict(x_test)

# %%
r2_score(y_test,y_test_pred)

# %%
y_train

# %%
y_train_pred

# %%
pd.DataFrame([[y_train,y_train_pred]])

# %%
mlr.coef_

# %%
mlr.intercept_

# %%
#How i get the prediction values
# solving by equation
y=-0.21032701*1 +(-0.23045363*2)+(0.45048237*3) +(0.00970423*4)+27

# %%
x_train

# %%
y42= (-0.21032701*102) +(-0.23045363*92)+(0.45048237*117.461264) +(0.00970423*30.527427)+27

# %%
y42

# %%
error= y_train- yTrain_pred

# %%
from matplotlib import pyplot as plt

# %%
#Test homoscatcity
plt.scatter(x=x_test["HP"], y_train= error)
plt.title("Homoscedsticity check- HP VS Eroor")
plt.xlabel("X")
plt.ylabel("Error")
plt.show()

# %%
# test for zero resussial
plt.scatter(x-test, y_test_pred)

# %%
x1= cars[["HP"]
y1= cats[["MPG"]]
mlr=LinearReggression()
mlr1.fit(X1,y1)
y1_pred= mlr1.predict(x1)
r2_score(y1,y1_pred)
