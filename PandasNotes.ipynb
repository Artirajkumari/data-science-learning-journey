# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\ArtiR\Downloads\Euro_2012_stats_TEAM.csv")
df
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# it is used to print total row and column
df.shape
# Out:
# (16, 35)

# %%
# print all column
df.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
# it print top five records by default it is five
df.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
 it print botom five records
df.tail()
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 11             36.8%             5.2%                          28
# 12             22.5%            12.5%                          59
# 13             55.9%            16.0%                         100
# 14             47.2%            13.8%                          39
# 15             21.2%             6.0%                          38
#
#     Hit Woodwork  Penalty goals  Penalties not scored  ...  Saves made  \
# 11             0              0                     0  ...          17
# ...

# %%
 #it is used to print type of clmn
df.dtypes
# Out:
# Team                           object
# Goals                           int64
# Shots on target                 int64
# Shots off target                int64
# Shooting Accuracy              object
# % Goals-to-shots               object
# Total shots (inc. Blocked)      int64
# Hit Woodwork                    int64
# Penalty goals                   int64
# Penalties not scored            int64
# Headed goals                    int64
# Passes                          int64
# Passes completed                int64
# Passing Accuracy               object
# Touches                         int64
# Crosses                         int64
# Dribbles                        int64
# Corners Taken                   int64
# Tackles                         int64
# Clearances                      int64
# Interceptions                   int64
# Clearances off line           float64
# Clean Sheets                    int64
# Blocks                          int64
# Goals conceded                  int64
# ...

# %%
 # it is print  null values if null is there than print true else print false
df.isna()
# Out:
#      Team  Goals  Shots on target  Shots off target  Shooting Accuracy  \
# 0   False  False            False             False              False
# 1   False  False            False             False              False
# 2   False  False            False             False              False
# 3   False  False            False             False              False
# 4   False  False            False             False              False
# 5   False  False            False             False              False
# 6   False  False            False             False              False
# 7   False  False            False             False              False
# 8   False  False            False             False              False
# 9   False  False            False             False              False
# 10  False  False            False             False              False
# 11  False  False            False             False              False
# ...

# %%
# it is used to print  total null values in  each column
df.isnull(). sum()
# Out:
# Team                          0
# Goals                         0
# Shots on target               0
# Shots off target              0
# Shooting Accuracy             0
# % Goals-to-shots              0
# Total shots (inc. Blocked)    0
# Hit Woodwork                  0
# Penalty goals                 0
# Penalties not scored          0
# Headed goals                  0
# Passes                        0
# Passes completed              0
# Passing Accuracy              0
# Touches                       0
# Crosses                       0
# Dribbles                      0
# Corners Taken                 0
# Tackles                       0
# Clearances                    0
# Interceptions                 0
# Clearances off line           1
# Clean Sheets                  0
# Blocks                        0
# Goals conceded                0
# Saves made                    0
# Saves-to-shots ratio          0
# Fouls Won                     0
# Fouls Conceded                0
# ...

# %%
# info print to all the information about the table
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %%
##iloc= by using index value we extract the data
# loc=  by using row & clmn name we extract the 

# iloc[first mention(start val: end val:step size), again for colmn same] 
df.iloc[ :,0:5]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
df.iloc[:6:1, -5::1]
# Out:
#    Yellow Cards  Red Cards  Subs on  Subs off  Players Used
# 0             9          0        9         9            16
# 1             7          0       11        11            19
# 2             4          0        7         7            15
# 3             5          0       11        11            16
# 4             6          0       11        11            19
# 5             4          0       15        15            17

# %%
df.iloc[:,:]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# before ccomma it is used for row and after comma for column
df.iloc[: : 2, 1::2]
# Out:
#     Goals  Shots off target % Goals-to-shots  Hit Woodwork  \
# 0       4                12            16.0%             0
# 2       4                10            20.0%             1
# 4       3                24             6.5%             1
# 6       5                18            19.2%             1
# 8       2                36             4.1%             2
# 10      6                42             9.3%             6
# 12      5                31            12.5%             2
# 14      5                19            13.8%             3
#
#     Penalties not scored  Passes Passing Accuracy  Crosses  Corners Taken  \
# 0                      0    1076            76.9%       60             14
# 2                      0    1298            83.3%       43             16
# 4                      0    2066            87.2%       55             28
# 6                      1    1187            76.7%       52             10
# ...

# %%
# to use ectraxt the random value
df.iloc[[1,2,7,9,10] , [8,4,7,11]]
# Out:
#     Penalty goals Shooting Accuracy  Hit Woodwork  Passes
# 1               0             41.9%             0    1565
# 2               0             50.0%             1    1298
# 7               0             43.0%             2    3016
# 9               0             39.4%             0    1059
# 10              0             34.3%             6    1891

# %%
df.loc[0:5,'Team':	'Shooting Accuracy']
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%

# %%
df.loc[ : , ['Team','Tackles','Red Cards']]
# Out:
#                    Team  Tackles  Red Cards
# 0               Croatia       49          0
# 1        Czech Republic       62          0
# 2               Denmark       40          0
# 3               England       86          0
# 4                France       71          0
# 5               Germany       91          0
# 6                Greece       65          1
# 7                 Italy       98          0
# 8           Netherlands       34          0
# 9                Poland       67          1
# 10             Portugal       78          0
# 11  Republic of Ireland       45          1
# 12               Russia       65          0
# 13                Spain      122          0
# 14               Sweden       56          0
# 15              Ukraine       65          0

# %%
# fetchin the data based on condition
df['Red Cards']==1
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# Name: Red Cards, dtype: bool

# %%
df['Tackles']>60
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8     False
# 9      True
# 10     True
# 11    False
# 12     True
# 13     True
# 14    False
# 15     True
# Name: Tackles, dtype: bool

# %%
(df['Red Cards']==1) & (df['Tackles']>60)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# dtype: bool

# %%
df[(df['Red Cards']==1) & (df['Tackles']>60)]
# Out:
#      Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 6  Greece      5                8                18             30.7%
# 9  Poland      2               15                23             39.4%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 6            19.2%                          32             1              1
# 9             5.2%                          48             0              0
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 6                     1  ...          13                 65.1%         67
# 9                     0  ...           6                 66.7%         48
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 6             48        12             9          1       12        12
# 9             56         3             7          1        7         7
#
#    Players Used
# 6            20
# 9            17
#
# [2 rows x 35 columns]

# %%
df[(df['Goals']==2) | (df['Penalty goals']==1)]
# Out:
#            Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5       Germany     10               32                32             47.8%
# 6        Greece      5                8                18             30.7%
# 8   Netherlands      2               12                36             25.0%
# 9        Poland      2               15                23             39.4%
# 13        Spain     12               42                33             55.9%
# 15      Ukraine      2                7                26             21.2%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 6             19.2%                          32             1              1
# 8              4.1%                          60             2              0
# 9              5.2%                          48             0              0
# ...

# %%
df[(df['Hit Woodwork']==0) & (df['Saves-to-shots ratio']>=60)]

# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\ArtiR\Downloads\Sales Transactions-2017.csv")
df
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
df1= pd.read_csv(r"C:\Users\ArtiR\Downloads\Sales Transactions-2018.csv")
df1
# Out:
#              Date   Voucher        Party            Product           Qty  \
# 0        1/4/2018   Sal:146         TP13  SILVER POUCH 9*12            50
# 1        1/4/2018   Sal:146         TP13             RUBBER             5
# 2        1/4/2018   Sal:146         TP13   DURGA 10*12 Blue      1,600.00
# 3        1/4/2018   Sal:146         TP13   DURGA 13*16 BLUE           400
# 4        1/4/2018   Sal:146         TP13    10*12 SARAS-NAT           600
# ...           ...       ...          ...                ...           ...
# 44735  31/03/2019  Sal:9610  HAMPI FOODS        SPOON SOOFY           200
# 44736         NaN       NaN          NaN                NaN           NaN
# 44737         NaN       NaN          NaN                NaN           NaN
# 44738         NaN   Total            NaN                NaN    666,056.00
# 44739         NaN   Total            NaN                NaN  7,097,803.00
#
#                 Rate           Gross        Disc  Voucher Amount
# ...

# %%
df2= pd.read_csv(r"C:\Users\ArtiR\Downloads\Sales Transactions-2019.csv")
df2
# Out:
#              Date   Voucher            Party         Product           Qty  \
# 0        1/4/2019   Sal:687  BALAJI PLASTICS   DONA-VAI-9100             1
# 1        1/4/2019   Sal:687  BALAJI PLASTICS  SMART BOUL(48)             1
# 2        1/4/2019   Sal:688  BALAJI PLASTICS      Vishnu Ice           110
# 3                                       28/3                             0
# 4        1/4/2019   Sal:689  BALAJI PLASTICS     100LEAF -SP             3
# ...           ...       ...              ...             ...           ...
# 19171  10/10/2019  Sal:4935        K.SRIHARI  13*16 WHITE RK           400
# 19172         NaN       NaN              NaN             NaN           NaN
# 19173         NaN       NaN              NaN             NaN           NaN
# 19174         NaN   Total                NaN             NaN     99,284.90
# 19175         NaN   Total                NaN             NaN  2,710,193.00
#
#                Rate          Gross        Disc Voucher Amount
# ...

# %%
 # concat the three table if all column  name is same
complt_data= pd.concat([df,df1,df2],ignore_index= True)
complt_data
# Out:
#               Date   Voucher               Party            Product  \
# 0         1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1         1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2         1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3         1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4         1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...            ...       ...                 ...                ...
# 111201  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 111202         NaN       NaN                 NaN                NaN
# 111203         NaN       NaN                 NaN                NaN
# 111204         NaN   Total                   NaN                NaN
# 111205         NaN   Total                   NaN                NaN
#
#                  Qty          Rate          Gross        Disc Voucher Amount
# ...

# %%
insur= pd.read_csv(r"C:\Users\ArtiR\Downloads\insurance.csv")
insur
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
# 
insur.groupby('sex')[['age']].agg(['min','max','mean'])
# Out:
#        age
#        min max       mean
# sex
# female  18  64  39.503021
# male    18  64  38.917160

# %%
insur.groupby('region')[['expenses', 'bmi']].mean().sort_values(by= 'expenses', ascending= False).round(2
                                                                                                )
# Out:
#            expenses    bmi
# region
# southeast  14735.41  33.36
# northeast  13406.38  29.18
# northwest  12417.58  29.20
# southwest  12346.94  30.60

# %%
insur.groupby('region')[['expenses']].agg('mean')
# Out:
#                expenses
# region
# northeast  13406.384691
# northwest  12417.575169
# southeast  14735.411538
# southwest  12346.937908
